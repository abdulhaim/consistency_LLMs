# %%
import json
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
class Dataset:
    def __init__(self, paths: list):
        self.paths = paths
        self.df = self.create_dataframe()

    def create_dataframe(self):
        data = []
        for path in self.paths:
            with open(path, 'r') as file:
                data.append(json.load(file))
        flat_data = [item for sublist in data for item in sublist]

        model_names = []
        for path, records in zip(self.paths, data):
            match = re.search(r'([^/]+?)(?:_\d+_\d+)?\.json$', os.path.basename(path))
            model_name = match.group(1) if match else ''
            model_names.extend([model_name] * len(records))
        
        for record, model_name in zip(flat_data, model_names):
            record['model_name'] = model_name
        
        return pd.DataFrame(flat_data)
    
    def add_to_dataframe(self, new_paths: list):
        new_data = []
        for path in new_paths:
            with open(path, 'r') as file:
                new_data.append(json.load(file))
        flat_new_data = [item for sublist in new_data for item in sublist]
        model_names = []

        for path, records in zip(new_paths, new_data):
            match = re.search(r'([^/]+?)(?:_\d+_\d+)?\.json$', os.path.basename(path))
            model_name = match.group(1) if match else ''
            model_names.extend([model_name] * len(records))

        for record, model_name in zip(flat_new_data, model_names):
            record['model_name'] = model_name

        new_df = pd.DataFrame(flat_new_data)
        self.df = pd.concat([self.df, new_df], ignore_index=True)
        self.paths.extend(new_paths)

# %%
file_paths = [
    "/nfs/kun2/users/ryan_cheng/consistency_LLMs/education/exp/05.12.25/Llama-3.1-8B-Instruct_0_138.json",
    "/nfs/kun2/users/ryan_cheng/consistency_LLMs/chatting/exp/04.26.25/Llama-3.1-8B-Instruct_0_623.json",
    "/nfs/kun2/users/ryan_cheng/consistency_LLMs/therapy/exp/05.14.25.marwa/Llama-3.1-8B-Instruct_10_932.json"
]

data = Dataset(file_paths)
data.df
# Out:
#       task_name               topic          grade P1  \
# 0     Education  The Nervous System    high school
# 1     Education  The Nervous System    high school
# 2     Education  The Nervous System    high school
# 3     Education  The Nervous System    high school
# 4     Education       The Parthenon  middle school
# ...         ...                 ...            ... ..
# 1195    Therapy
# 1196    Therapy
# 1197    Therapy
# 1198    Therapy
# 1199    Therapy
#
#                                                      P2  \
# 0     As a high school student with an Intrapersonal...
# 1     As a high school student with an Intrapersonal...
# 2     As a high school student with an Intrapersonal...
# 3     As a high school student with an Intrapersonal...
# 4     As a middle school student with an Auditory le...
# ...                                                 ...
# 1195  You are Jason, a 27-year-old graphic designer ...
# 1196  You are Chloe, a 34-year-old personal trainer ...
# 1197  You are Chloe, a 34-year-old personal trainer ...
# 1198  You are Chloe, a 34-year-old personal trainer ...
# 1199  You are Chloe, a 34-year-old personal trainer ...
#
#                                            conversation  pturn  index  \
# 0     [[0, Teacher: Let's break down the nervous sys...      1      0
# 1     [[0, Teacher: Let's dive into the fascinating ...      1      1
# 2     [[0, Teacher: Let's dive into the fascinating ...      1      2
# 3     [[0, Teacher: I'd love to teach you about the ...      1      3
# 4     [[0, Teacher: Let's start by exploring the bas...      1      4
# ...                                                 ...    ...    ...
# 1195  [[0, Therapist: You seemed to use the word "st...      1    395
# 1196  [[0, Therapist: What comes up for you when you...      1    396
# 1197  [[0, Therapist: Can you tell me more about wha...      1    397
# 1198  [[0, Therapist: How can I help you make sense ...      1    398
# 1199  [[0, Therapist: How did you come to that reali...      1    399
#
#                 timestamp  rounds  ...  \
# 0     2025-05-12 20:55:19      10  ...
# 1     2025-05-12 20:55:28      20  ...
# 2     2025-05-12 20:55:49      40  ...
# 3     2025-05-12 20:56:25      60  ...
# 4     2025-05-12 20:56:28      10  ...
# ...                   ...     ...  ...
# 1195                           60  ...
# 1196                           10  ...
# 1197                           20  ...
# 1198                           40  ...
# 1199                           60  ...
#
#                                       P2_backstory_test  \
# 0     [[Question: As a high school student with an I...
# 1     [[Question: As an individual with an Intrapers...
# 2     [[Question: As a high school student with an I...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1195                                                NaN
# 1196                                                NaN
# 1197                                                NaN
# 1198                                                NaN
# 1199                                                NaN
#
#                                 eval_survey_consistency  \
# 0     [[Student: I'm really interested in this becau...
# 1     [[Student: I think it's really cool that our b...
# 2     [[Student: That sounds awesome, I'm really cur...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1195                                                NaN
# 1196                                                NaN
# 1197                                                NaN
# 1198                                                NaN
# 1199                                                NaN
#
#                         eval_prompt_2_stage_consistency  \
# 0     [[1, The Student's intention behind this line ...
# 1     [[1, The Student's statement reveals an intent...
# 2     [[1, The Student's intention behind the line i...
# 3     [[1, The intention behind the Student's statem...
# 4     [[1, The Student's question about the Partheno...
# ...                                                 ...
# 1195  [[1, The intention behind Jason's statement is...
# 1196  [[1, The intention behind the patient's statem...
# 1197  [[1, The intention behind the patient's statem...
# 1198  [[1, The patient's statement suggests that the...
# 1199  [[1, The intention behind the patient's statem...
#
#      P2_prompt_2_stage_consistency_score             model_name  \
# 0                               1.000000  Llama-3.1-8B-Instruct
# 1                               1.000000  Llama-3.1-8B-Instruct
# 2                               1.000000  Llama-3.1-8B-Instruct
# 3                               1.000000  Llama-3.1-8B-Instruct
# 4                               0.600000  Llama-3.1-8B-Instruct
# ...                                  ...                    ...
# 1195                            0.533333  Llama-3.1-8B-Instruct
# 1196                            0.600000  Llama-3.1-8B-Instruct
# 1197                            0.600000  Llama-3.1-8B-Instruct
# 1198                            0.700000  Llama-3.1-8B-Instruct
# 1199                            0.366667  Llama-3.1-8B-Instruct
#
#       P1_prompt_consistency_score P1_index_consistency_score  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 1195                          0.0                        NaN
# 1196                          0.0                        NaN
# 1197                          0.0                        NaN
# 1198                          0.0                        NaN
# 1199                          0.0                        NaN
#
#      P1_survey_consistency_score P1_backstory_test  \
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                            NaN               NaN
# 3                            NaN               NaN
# 4                            NaN               NaN
# ...                          ...               ...
# 1195                         NaN               NaN
# 1196                         NaN               NaN
# 1197                         NaN               NaN
# 1198                         NaN               NaN
# 1199                         NaN               NaN
#
#       P1_prompt_2_stage_consistency_score
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 1195                                  NaN
# 1196                                  NaN
# 1197                                  NaN
# 1198                                  NaN
# 1199                                  NaN
#
# [1200 rows x 26 columns]

# %%
def plot_consistency_comparison(data, scenario):
    education_only = data.df[data.df["task_name"] == scenario]
    plt.figure(figsize=(20, 10))
    plt.plot(education_only["index"], education_only["P2_prompt_consistency_score"], label="Original", color="blue")
    plt.plot(education_only["index"], education_only["P2_prompt_2_stage_consistency_score"], label="2 stage", color="orange")
    plt.legend()
    plt.xlabel("Index")
    plt.ylabel("Consistency Score")
    plt.title(f"Consistency Scores for {scenario} Task")
    plt.show()

# %%
plot_consistency_comparison(data, "Chatting")

# %%
plot_consistency_comparison(data, "Education")

# %%
plot_consistency_comparison(data, "Therapy")

# %% [markdown]
# # Load File paths

# %%
file_paths = [
    "./therapy/exp/05.15.25/long_gemma-2-2b-it_0_897.json",
    "./therapy/exp/05.15.25/long_Llama-3.1-8B-Instruct_0_336.json",
    "./therapy/exp/05.15.25/long_mistral-instruct_0_959.json"
]

# %%
data = []
for path in file_paths:
    with open(path, 'r') as f:
        data.append(json.load(f))

flat_data = [item for sublist in data for item in sublist]

# %%
import re

model_names = []
for path, records in zip(file_paths, data):
    match = re.search(r'long_([^_]+)', os.path.basename(path))
    model_name = match.group(1) if match else ''
    model_names.extend([model_name] * len(records))

for record, model_name in zip(flat_data, model_names):
    record['model_name'] = model_name

df = pd.DataFrame(flat_data)

# %%
file_paths2 = [
    "./therapy/exp/05.14.25.marwa/gemma-2-2b-it_10_259.json",
    "./therapy/exp/05.14.25.marwa/Llama-3.1-8B-Instruct_10_932.json",
    "./therapy/exp/05.14.25.marwa/mistral-instruct_10_186.json",
    "./therapy/exp/05.14.25.marwa/mistral-instruct_0_501.json",
    "./therapy/exp/05.14.25.marwa/mistral-instruct_0_261.json"
]

# %%
# Load data from file_paths2 and append to the existing dataframe df

data2 = []
for path in file_paths2:
    with open(path, 'r') as f:
        data2.append(json.load(f))

flat_data2 = [item for sublist in data2 for item in sublist]

model_names2 = []
for path, records in zip(file_paths2, data2):
    match = re.search(r'([^/]+?)(?:_\d+_\d+)?\.json$', os.path.basename(path))
    model_name = match.group(1) if match else ''
    model_names2.extend([model_name] * len(records))

for record, model_name in zip(flat_data2, model_names2):
    record['model_name'] = model_name

df2 = pd.DataFrame(flat_data2)

# Concatenate with the existing df
df = pd.concat([df, df2], ignore_index=True)

# %%
df.head()
# Out:
#   task_name topic grade P1                                                 P2  \
# 0   Therapy                 You are Alex, a 34-year-old IT technician with...
# 1   Therapy                 You are Alex, a 34-year-old IT technician with...
# 2   Therapy                 You are Alex, a 34-year-old IT technician with...
# 3   Therapy                 You are Riley, a 28-year-old freelance artist ...
# 4   Therapy                 You are Riley, a 28-year-old freelance artist ...
#
#                                         conversation  pturn  index  \
# 0  [[0, Therapist: Welcome! It's wonderful to mee...      1      0
# 1  [[0, Therapist: You mentioned that you feel st...      1      0
# 2  [[0, Therapist: How has this struggle been imp...      1      1
# 3  [[0, Therapist: How can you tell it's been a y...      1      2
# 4  [[0, Therapist: What's been on your mind latel...      1      3
#
#              timestamp  rounds  conversation_only             model_name  \
# 0  2025-05-15 12:16:42     200               True          gemma-2-2b-it
# 1  2025-05-15 12:48:10     200               True  Llama-3.1-8B-Instruct
# 2  2025-05-15 12:50:32     300               True  Llama-3.1-8B-Instruct
# 3  2025-05-15 12:52:02     200               True  Llama-3.1-8B-Instruct
# 4  2025-05-15 12:54:22     300               True  Llama-3.1-8B-Instruct
#
#                              eval_prompt_consistency  \
# 0                                                NaN
# 1  [[1, The intention behind the patient's statem...
# 2  [[1, The intention behind this statement is fo...
# 3  [[1, The intention behind the patient's line i...
# 4  [[1, The intention behind this line appears to...
#
#    P2_prompt_consistency_score  \
# 0                          NaN
# 1                     0.450000
# 2                     0.306667
# 3                     0.050000
# 4                     0.066667
#
#                               eval_index_consistency  \
# 0                                                NaN
# 1  [[3, This line is consistent with the conversa...
# 2  [[3, The line is consistent with the previous ...
# 3  [[3, This line is consistent with the patient'...
# 4  [[3, The current line does not seem to have an...
#
#    P2_index_consistency_score  P2_survey_consistency_score  \
# 0                         NaN                          NaN
# 1                    0.989899                     3.650000
# 2                    0.998658                     3.653333
# 3                    0.997172                     3.930000
# 4                    0.994631                     2.386667
#
#                                    P2_backstory_test  \
# 0                                                NaN
# 1  [[Question: You've just successfully debugged ...
# 2  [[Question: You've just fixed a critical issue...
# 3  [[Question: As someone who keeps conversations...
# 4  [[Question: When someone asks you about your f...
#
#                              eval_survey_consistency  \
# 0                                                NaN
# 1  [[Patient: Honestly, I just feel like I'm not ...
# 2  [[Patient: To be honest, I think I push people...
# 3  [[Patient: It still feels like it happened yes...
# 4  [[Patient: I've been struggling to meet deadli...
#
#    P1_prompt_consistency_score
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %%
# Group by conversation length and model name
grouped = df.groupby(['model_name', 'rounds']).agg(
    conversation_len=('conversation', lambda x: len(x.iloc[0]) if len(x) > 0 else 0),
    avg_prompt_consistency=('P2_prompt_consistency_score', 'mean'),
    std_prompt_consistency=('P2_prompt_consistency_score', 'std')
).reset_index()

plt.figure(figsize=(8, 5))
for model in grouped['model_name'].unique():
    model_data = grouped[grouped['model_name'] == model]
    plt.errorbar(
        model_data['conversation_len'],
        model_data['avg_prompt_consistency'],
        yerr=model_data['std_prompt_consistency'],
        marker='o',
        label=model,
        capsize=5
    )

plt.xlabel('Conversation Length')
plt.ylabel('Average Prompt Consistency Score')
plt.title('Conversation Length vs. Average Prompt Consistency Score by Model')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Side-by-side bar plot for each model and conversation length

plot_data = grouped.dropna(subset=['avg_prompt_consistency'])

models = plot_data['model_name'].unique()
x = plot_data['conversation_len'].unique()
x.sort()
bar_width = 0.25
positions = np.arange(len(x))

plt.figure(figsize=(10, 6))

for i, model in enumerate(models):
    model_data = plot_data[plot_data['model_name'] == model]
    # Align bars for missing conversation lengths
    y = []
    yerr = []
    for conv_len in x:
        row = model_data[model_data['conversation_len'] == conv_len]
        if not row.empty:
            y.append(row['avg_prompt_consistency'].values[0])
            yerr.append(row['std_prompt_consistency'].values[0])
        else:
            y.append(np.nan)
            yerr.append(0)
    plt.bar(positions + i * bar_width, y, bar_width, yerr=yerr, label=model, capsize=5)

plt.xlabel('Conversation Length')
plt.ylabel('Average Prompt Consistency Score')
plt.title('Average Prompt Consistency Score by Model and Conversation Length')
plt.xticks(positions + bar_width, x)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Same plot for P2_index_consistency_score
grouped_index = df.groupby(['model_name', 'rounds']).agg(
    conversation_len=('conversation', lambda x: len(x.iloc[0]) if len(x) > 0 else 0),
    avg_index_consistency=('P2_index_consistency_score', 'mean'),
    std_index_consistency=('P2_index_consistency_score', 'std')
).reset_index()

plt.figure(figsize=(8, 5))
for model in grouped_index['model_name'].unique():
    model_data = grouped_index[grouped_index['model_name'] == model]
    plt.errorbar(
        model_data['conversation_len'],
        model_data['avg_index_consistency'],
        yerr=model_data['std_index_consistency'],
        marker='o',
        label=model,
        capsize=5
    )

plt.xlabel('Conversation Length')
plt.ylabel('Average Pairwise Consistency Score')
plt.title('Conversation Length vs. Average Pairwise Consistency Score by Model')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Bar plot for P2_index_consistency_score

plot_data_index = grouped_index.dropna(subset=['avg_index_consistency'])

models = plot_data_index['model_name'].unique()
x = plot_data_index['conversation_len'].unique()
x.sort()
bar_width = 0.25
positions = np.arange(len(x))

plt.figure(figsize=(10, 6))

for i, model in enumerate(models):
    model_data = plot_data_index[plot_data_index['model_name'] == model]
    y = []
    yerr = []
    for conv_len in x:
        row = model_data[model_data['conversation_len'] == conv_len]
        if not row.empty:
            y.append(row['avg_index_consistency'].values[0])
            yerr.append(row['std_index_consistency'].values[0])
        else:
            y.append(np.nan)
            yerr.append(0)
    plt.bar(positions + i * bar_width, y, bar_width, yerr=yerr, label=model, capsize=5)

plt.xlabel('Conversation Length')
plt.ylabel('Average Pairwise Consistency Score')
plt.title('Average Pairwise Consistency Score by Model and Conversation Length')
plt.xticks(positions + bar_width, x)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Survey consistency line plot

grouped_survey = df.groupby(['model_name', 'rounds']).agg(
    conversation_len=('conversation', lambda x: len(x.iloc[0]) if len(x) > 0 else 0),
    avg_survey_consistency=('P2_survey_consistency_score', 'mean'),
    std_survey_consistency=('P2_survey_consistency_score', 'std')
).reset_index()

plot_data_survey = grouped_survey.dropna(subset=['avg_survey_consistency'])

plt.figure(figsize=(8, 5))
for model in plot_data_survey['model_name'].unique():
    model_data = plot_data_survey[plot_data_survey['model_name'] == model]
    plt.errorbar(
        model_data['conversation_len'],
        model_data['avg_survey_consistency'],
        yerr=model_data['std_survey_consistency'],
        marker='o',
        label=model,
        capsize=5
    )

plt.xlabel('Conversation Length')
plt.ylabel('Average Survey Consistency Score')
plt.title('Conversation Length vs. Average Survey Consistency Score by Model')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Survey consistency bar plot

models = plot_data_survey['model_name'].unique()
x = plot_data_survey['conversation_len'].unique()
x.sort()
bar_width = 0.25
positions = np.arange(len(x))

plt.figure(figsize=(10, 6))

for i, model in enumerate(models):
    model_data = plot_data_survey[plot_data_survey['model_name'] == model]
    y = []
    yerr = []
    for conv_len in x:
        row = model_data[model_data['conversation_len'] == conv_len]
        if not row.empty:
            y.append(row['avg_survey_consistency'].values[0])
            yerr.append(row['std_survey_consistency'].values[0])
        else:
            y.append(np.nan)
            yerr.append(0)
    plt.bar(positions + i * bar_width, y, bar_width, yerr=yerr, label=model, capsize=5)

plt.xlabel('Conversation Length')
plt.ylabel('Average Survey Consistency Score')
plt.title('Average Survey Consistency Score by Model and Conversation Length')
plt.xticks(positions + bar_width, x)
plt.legend()
plt.tight_layout()
plt.show()
