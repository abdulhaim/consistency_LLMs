# %%
# %env CUDA_VISIBLE_DEVICES=0
# %env TMPDIR=/raid/users/ryan_cheng/tmp
import os
import glob
import re
import json
import random
import time
from absl import app, flags
from tqdm import tqdm
from datetime import datetime
import openai
from openai import OpenAI
from transformers import AutoTokenizer
import pandas as pd
import numpy as np

np.random.seed(0)

try:
    from vllm import LLM, SamplingParams
    import ray
except ImportError:
    pass
with open(os.path.abspath('../ryan_openai.txt'), 'r') as f:
    # ../.. for notebook, .. for script
    client = OpenAI(api_key=f.read().rstrip('\n'))

vllm_models = [
    'meta-llama/Llama-2-13b-hf', 'Llama-2-13b-hf', 'Llama13b', 'llama13b',
    'mistralai/Mistral-7B-v0.1', 'Mistral', 'mistral',
    'mistralai/Mixtral-8x7B-v0.1', 'Mixtral', 'mixtral',
    'meta-llama/Llama-2-70b-hf', 'Llama-2-70b-hf', 'Llama70b', 'llama70b',
    'meta-llama/Meta-Llama-3-70B-Instruct', 'Llama-3-70B-Instruct', 'meta-llama/Llama-3.1-70B-Instruct', 'meta-llama/Llama-3.1-8B-Instruct',
    'meta-llama/Meta-Llama-3-8B-Instruct', 'Llama-3-8B-Instruct',
    'mistralai/Mistral-7B-Instruct-v0.1', 'mistral-instruct',
    'google/gemma-7b', 'gemma'
]

# run 'ray start --head --num-gpus <NUM>' in bash first!
def setup_llm(model_name, config):
    if model_name not in vllm_models:
        return None, None
    if config['gpus'] > 1:
        ray.init(ignore_reinit_error=True)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    llm = LLM(model=model_name, tensor_parallel_size=config['gpus'], download_dir='/raid/users/ryan_cheng/models', gpu_memory_utilization=0.95, max_model_len=41632)
    return llm, tokenizer

def completion_create_helper(model_name, config, prompt, llm=None):
    # limit prompt in all cases
    if model_name not in vllm_models:
        # for some reason vLLM models simply repeat this last statement if present
        prompt += " Limit your answer to three sentences or less!"

    ret = '' # return the output ret at the end and use to calculate cost

    if model_name == "gpt-3.5-turbo-instruct":
        ret = client.completions.create(
                model="gpt-3.5-turbo-instruct",
                prompt=prompt,
                temperature=0.8,
                max_tokens=config['max_tokens'],
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0
        )
        ret = ret.choices[0].text.strip()
        #find_line = ret.find("\n")
        #if find_line != -1:
            #ret = ret[:find_line]
    elif model_name in ["gpt-3.5-turbo", "gpt-3.5-turbo-16k", "gpt-4-turbo", "gpt-4o", "gpt-4o-mini"]:
        ret = client.chat.completions.create(
            model=model_name,
            messages=[{"role": "system", "content": prompt}],
            max_tokens=config['max_tokens']
        )
        ret = ret.choices[-1].message.content

    elif model_name in vllm_models and llm:
        sampling_params = SamplingParams(temperature=0.8, top_p=0.95, max_tokens=config['max_tokens'])
        output = llm.generate([prompt], sampling_params)
        ret = output[0].outputs[0].text
    else:
        raise NotImplementedError

    # if config['model'] not in vllm_models:
    #     running_cost_for_iteration += api_cost(prompt=prompt, answer=ret, model=config['model'])
    #     if config['verbose']:
    #         print(f"RUNNING COST FOR ITERATION SO FAR: {running_cost_for_iteration}")
    
    return ret

def completion_create(model_name, config, prompt, llm=None, keep_trying=True):
    try:
        return completion_create_helper(model_name, config, prompt, llm)
    except (openai.APIError, openai.OpenAIError) as e:
        # print("ERROR", e)
        # print("sleeping for 10 seconds.")
        time.sleep(10)
        if keep_trying:
            return completion_create(model_name, config, prompt, llm, keep_trying)
        else:
            return None
            
def write_json(write_path, json_dict):
    if not os.path.exists(write_path):
        with open(write_path, 'w') as f:
            json.dump([], f)
    with open(write_path, 'r') as f:
        evaluations = json.load(f)
    evaluations.append(json_dict)
    with open(write_path, 'w') as f:
        json.dump(evaluations, f, indent=4)
# Out:
# env: CUDA_VISIBLE_DEVICES=0
# env: TMPDIR=/raid/users/ryan_cheng/tmp

# %%
config_gpt4_mini = {
    'agent1_model': 'gpt-4o-mini',
    'agent2_model': 'gpt-4o-mini',
    'eval_model': 'gpt-4o-mini',
    'agent1_role': "\nPerson 1: ",
    'agent2_role': "\nPerson 2: ",
    #'generic_prompt': generic, 
    #'agent1_specific': agent_1_specific + do_not_repeat_text, 
    #'agent2_specific': agent_2_specific + do_not_repeat_text,
    #'eval_prompts': eval_prompts,
    'iterations': 1, # not used
    'verbose': True, # not used
    'write': True,
    'convo_length_limit': 10,
    'max_tokens': 256,
    'gpus': 2,
    'task_name': 'Persona Chat',
}

# %% [markdown]
# # Persona Chat Generation

# %%
persona_chat = pd.read_csv('./data/persona/personality.csv')
persona_chat.head()
# Out:
#    Unnamed: 0                                            Persona  \
# 0           0   i like to remodel homes. i like to go hunting...
# 1           1   my mom is my best friend. i have four sisters...
# 2           2   i had a gig at local theater last night. i wo...
# 3           3   i am very athletic. i wear contacts. i have b...
# 4           4   i am primarily a meat eater. i am a guitar pl...
#
#                                                 chat
# 0  hi , how are you doing ? i am getting ready to...
# 1  hi , how are you doing today ?\ni am spending ...
# 2  we all live in a yellow submarine , a yellow s...
# 3  hi ! i work as a gourmet cook .\ni do not like...
# 4  how are you doing today\nwhat do you do for ca...

# %%
print(persona_chat.iloc[0]["Persona"])
# Out:
#  i like to remodel homes. i like to go hunting. i like to shoot a bow. my favorite holiday is halloween.

# %%
print(persona_chat.iloc[0]["chat"])
# Out:
# hi , how are you doing ? i am getting ready to do some cheetah chasing to stay in shape .
# you must be very fast . hunting is one of my favorite hobbies .
# i am ! for my hobby i like to do canning or some whittling .
# i also remodel homes when i am not out bow hunting .
# that is neat . when i was in high school i placed 6th in 100m dash !
# that is awesome . do you have a favorite season or time of year ?
# i do not . but i do have a favorite meat since that is all i eat exclusively .
# what is your favorite meat to eat ?
# i would have to say its prime rib . do you have any favorite foods ?
# i like chicken or macaroni and cheese .
# do you have anything planned for today ? i think i am going to do some canning .
# i am going to watch football . what are you canning ?
# i think i will can some jam . do you also play footfall for fun ?
# if i have time outside of hunting and remodeling homes . which is not much !

# %%
random_indices = np.array([np.random.choice(len(persona_chat), size=2, replace=False) for _ in range(10)])
random_indices # pairs of indices of Persona to  use in conversation
# Out:
# array([[7710, 4426],
#        [5525, 2032],
#        [ 574, 6234],
#        [2303,  263],
#        [3890,  877],
#        [8913, 6509],
#        [7400, 2988],
#        [6578, 4878],
#        [5014, 8746],
#        [8254, 5155]])

# %%
persona_chat[persona_chat["chat"] == persona_chat.iloc[0]["chat"]]
# Out:
#    Unnamed: 0                                            Persona  \
# 0           0   i like to remodel homes. i like to go hunting...
#
#                                                 chat
# 0  hi , how are you doing ? i am getting ready to...

# %%
"".join(["a", "b"])
# Out:
# 'ab'

# %%
def generate_conversation(p1, p2, config, pturn=1, write=False, write_path='data/persona/persona_chat.json'):
    conv_dict = {
        "task_name": config['task_name'],
        "P1": p1,
        "P2": p2,
        "conversation": [],
        "pturn": pturn # beginning person (1 or 2)
        }
    round_num = 0
    while round_num < config['convo_length_limit']:
        if pturn == 1:
            prompt = "You are P1, and you are having a conversation with P2. Your backstory is:\n" + p1 + "\n" + "So far, the conversation is as below, and it is your turn to speak next.\n" + ("".join(conv_dict["conversation"]) if len(conv_dict["conversation"]) != 0 else "[You are starting the conversation.]") + "P1: "
            pturn = 2
            conv_dict["conversation"].append("P1: " + completion_create(config['agent1_model'], config, prompt) + "\n")
        else:
            prompt = "You are P2, and you are having a conversation with P1. Your backstory is:\n\n" + p2 + "\n\n" + "So far, the conversation is as below, and it is your turn to speak next.\n" + ("".join(conv_dict["conversation"]) if len(conv_dict["conversation"]) != 0 else "[You are starting the conversation.]") + "P2: "
            pturn = 1     
            conv_dict["conversation"].append("P2: " + completion_create(config['agent2_model'], config, prompt) + "\n")
        round_num += 1

    conv_dict["rounds"] = round_num
    if write:
        write_json(write_path, conv_dict)
    return conv_dict

# %%
conversations = []
for p1i, p2i in tqdm(random_indices):
    conversations.append(generate_conversation(persona_chat.iloc[p1i]["Persona"], persona_chat.iloc[p2i]["Persona"], config_gpt4_mini, write=True))
# Out:
# 100%|██████████| 10/10 [01:44<00:00, 10.50s/it]

# %%
conversations
# Out:
# [{'task_name': 'Persona Chat',
#   'P1': ' i like to cook. i have lived in several different states. i worked as a nurse for many years. my husband was a salesman. i have a cat named kj.',
#   'P2': ' i like fruit. my favorite fruit is apple. i don t like to eat meat. i like to eat the skin of the apple. i like green apples.',
#   'conversation': ["P1: P1: Hey! What’s your favorite meal to cook? I love trying out new recipes, especially since I've lived in so many different states and picked up various culinary influences along the way.\n",
#    "P2: I don't really cook meat, so I often make dishes that highlight fruits and vegetables. My favorite is a fresh apple salad with green apples, nuts, and a light dressing. It's simple, delicious, and lets the apple's flavor shine!\n",
#    'P1: That sounds refreshing! I love incorporating seasonal fruits and veggies into my dishes too. Is there a specific time of year when you enjoy making your apple salad the most?\n',
#    "P2: I love making my apple salad in the fall when the apples are crisp and juicy. It's the perfect time to enjoy the harvest and combine the flavors with some autumn spices. Plus, the vibrant colors of the ingredients make it visually appealing!\n",
#    'P1: I totally agree! Fall really does bring out the best in apples and the wonderful spices that accompany them. I often make warm dishes that complement the season, like a hearty apple and butternut squash bake. What other seasonal recipes do you enjoy?\n',
#    "P1: P2: Thanks, I appreciate your support! It would be incredible to create something that resonates with people and sparks important conversations about health and wellness. Maybe one day, we'll both find a way to merge our passions in storytelling!\n",
#    "P2: Absolutely! I think there's so much potential for collaboration between the arts and healthcare. Who knows, maybe one day we can create a project together that combines our strengths and passions!\n",
#    'P1: P2: That would be amazing! I can already envision a powerful narrative that highlights the human experience in healthcare while showcasing some incredible performances. Let’s keep that dream alive and inspire each other along the way!\n',
#    'P2: P1, I love that vision! It would be so rewarding to create something that brings awareness and connects with people on a personal level. Let’s definitely keep that dream alive and support each other as we pursue our passions!\n'],
#   'pturn': 1,
#   'rounds': 10},
#  {'task_name': 'Persona Chat',
#   'P1': ' i am weak and selfish , but i want to change. my mind is set on things above. i hate evil. i trust in god. my heart hurts from a broken relationship.',
#   'P2': ' i work in finance. i enjoy playing soccer. i live walking distance from work. i do not like coffee. i rent an apartment.',
#   'conversation': ["P1: P1: I've been reflecting a lot on my past choices, and I really want to make a change in my life. It's hard dealing with the pain from my broken relationship, but I trust that God has a plan for me. How do you find strength when you're feeling weak?\n",
#    'P2: I find strength through the little things in life, like playing soccer, which helps me clear my mind and stay active. Also, having a routine and a supportive network can really make a difference. It’s all about focusing on the positive aspects and taking one step at a time.\n',
#    'P1: P1: That makes so much sense. I need to focus on the little things too and lean on my support system more. Maybe finding a hobby or activity could help me heal and grow stronger.\n',
#    'P2: Absolutely! Hobbies can be a great outlet for your emotions and a way to meet new people. Have you considered trying something new, like joining a local sports club or taking up a creative class?\n',
#    'P1: P1: I think trying a new activity could be really beneficial for me. Maybe I could join a community group or take a class in something I’ve always been interested in. I just want to use this time to grow and heal in a positive way.\n',
#    'P2: That sounds like a wonderful idea! Exploring new interests can bring excitement and a fresh perspective. What types of activities are you thinking about trying?\n',
#    "P1: I'm really interested in taking a painting class or maybe even joining a local volunteering group. I think it would help me express myself and connect with others who share similar values. Plus, giving back could be a great way to combat the selfishness I've been struggling with.\n",
#    "P2: Those both sound like fantastic options! Painting can be a wonderful form of self-expression, and volunteering is a great way to connect with others and make a positive impact. I think you'll find that both activities will help you grow and heal in meaningful ways.\n",
#    "P1: P1: Thank you! I really appreciate your encouragement. I'm excited to explore these avenues and start this new chapter in my life.\n",
#    "P2: I'm glad to hear you're feeling excited about this new chapter! Embracing change can lead to incredible personal growth, and I'm sure you'll find joy in the painting and volunteering. If you ever want to share your experiences, I'm here to listen!\n"],
#   'pturn': 1,
#   'rounds': 10},
#  {'task_name': 'Persona Chat',
#   'P1': ' i have a collection of video games. i have a very tone body. my wife and i enjoy long sunday drives. my son is a straight a student.',
#   'P2': ' my mom is the best baker in my family. i am in my second year of medical school. i am a hindu living in louisiana. i have two children but i am divorced.',
#   'conversation': ["P1: P1: Hey, have you played any new video games lately? I've been diving into some classics from my collection and it's been a blast!\n",
#    "P2: P2: I haven't had much time for video games lately, especially with medical school and the kids keeping me busy. But I do enjoy a good game when I can squeeze it in! What classics are you playing?\n",
#    'P1: P1: I’ve been revisiting titles like "The Legend of Zelda: Ocarina of Time," "Super Mario 64," and "Final Fantasy VII." They really take me back to my childhood! It’s nice to escape for a bit, even with a busy schedule.\n',
#    'P2: P2: Those are some nostalgic classics! I can see how they would provide a nice escape. What do you enjoy most about revisiting those games?\n',
#    "P1: P1: I love the sense of nostalgia they bring, reminding me of simpler times. The storytelling and characters are so memorable, and I find that the gameplay feels timeless. Plus, it's fun to challenge myself to beat my old high scores!\n",
#    "P2: P2: I totally get that! The storytelling in those games really sticks with you, and it's great to immerse yourself in that world again. Do you have a favorite character from any of those games?\n",
#    'P1: P1: Definitely! I\'d have to say Link from "Zelda," Cloud from "Final Fantasy VII," and Mario himself are my favorites. Each character has such a unique journey and personality that makes them unforgettable. How about you? Any favorite characters from games you enjoyed?\n',
#    'P2: P2: I really love Ellie from "The Last of Us" for her depth and resilience, as well as Nathan Drake from "Uncharted" for his adventurous spirit. And I can\'t forget about Luigi—he\'s always been my underdog favorite with his charm! What about game mechanics or features do you find yourself appreciating more as you revisit these classics?\n',
#    'P1: P1: I really appreciate the simplicity of controls and the creativity in level design in these classics. The puzzles and exploration aspects are so engaging, and they often require thoughtful problem-solving. It’s amazing how timeless some of these mechanics feel even today!\n',
#    "P2: P2: I completely agree! The simplicity often lets the storytelling shine, and those clever puzzles keep you deeply engaged. It's a reminder of how effective great game design can be, even without all the modern bells and whistles!\n"],
#   'pturn': 1,
#   'rounds': 10}]

# %%
persona_chat.iloc[p1i]["Persona"]
# Out:
# ' i have a collection of video games. i have a very tone body. my wife and i enjoy long sunday drives. my son is a straight a student.'

# %%
persona_chat.iloc[p2i]["Persona"]
# Out:
# ' my mom is the best baker in my family. i am in my second year of medical school. i am a hindu living in louisiana. i have two children but i am divorced.'

# %% [markdown]
# # Consistency Evaluation

# %%
# (1) Takes in dialog, takes in base prompt, checks inconsistencies with base prompt for each line and output

def eval_prompt_consistency(conv_dict, config):
    #assert 'eval_prompt_consistency' not in conv_dict # warn if we are replacing metrics we don't mean to overwrite

    conv_dict['eval_prompt_consistency'] = []
    conv_dict['P1_prompt_consistency_score'] = 0
    conv_dict['P2_prompt_consistency_score'] = 0
    p1_utterances = 0
    p2_utterances = 0
    pturn = conv_dict["pturn"]
    for line in conv_dict["conversation"]:
        if pturn == 1:
            prompt = "For the following line spoken by P1, answer YES if the line contradicts the given backstory of P1, and answer NO if the line does not contradict the provided backstory of P1. P1's backstory is:\n" + conv_dict["P1"] + "\n P1 spoke the following line: \n" + line + "\n\n Answer YES if the line contradicts the given backstory of P1, and answer NO if the line does not contradict the provided backstory of P1, followed by 1 sentence of reasoning.\n\n"
            output = completion_create(config['eval_model'], config, prompt)
            conv_dict['eval_prompt_consistency'].append(output)
            if "YES" not in output: # no contradiction
                conv_dict['P1_prompt_consistency_score'] += 1
            p1_utterances += 1
            pturn = 2
        else:
            prompt = "For the following line spoken by P2, answer YES if the line contradicts the given backstory of P2, and answer NO if the line does not contradict the provided backstory of P2. P2's backstory is:\n" + conv_dict["P2"] + "\n P2 spoke the following line: \n" + line + "\n\n Answer YES if the line contradicts the given backstory of P2, and answer NO if the line does not contradict the provided backstory of P2, followed by 1 sentence of reasoning.\n\n"
            output = completion_create(config['eval_model'], config, prompt)
            conv_dict['eval_prompt_consistency'].append(output)
            if "YES" not in output: # no contradiction
                conv_dict['P2_prompt_consistency_score'] += 1
            p2_utterances += 1
            pturn = 1

    conv_dict['P1_prompt_consistency_score'] /= p1_utterances
    conv_dict['P2_prompt_consistency_score'] /= p2_utterances

# %%
conversation
# Out:
# {'task_name': 'Persona Chat',
#  'P1': ' i like to cook. i have lived in several different states. i worked as a nurse for many years. my husband was a salesman. i have a cat named kj.',
#  'P2': ' i like fruit. my favorite fruit is apple. i don t like to eat meat. i like to eat the skin of the apple. i like green apples.',
#  'conversation': ["P1: P1: Hey! What’s your favorite meal to cook? I love trying out new recipes, especially since I've lived in so many different states and picked up various culinary influences along the way.\n",
#   "P2: I don't really cook meat, so I often make dishes that highlight fruits and vegetables. My favorite is a fresh apple salad with green apples, nuts, and a light dressing. It's simple, delicious, and lets the apple's flavor shine!\n",
#   'P1: That sounds refreshing! I love incorporating seasonal fruits and veggies into my dishes too. Is there a specific time of year when you enjoy making your apple salad the most?\n',
#   "P2: I love making my apple salad in the fall when the apples are crisp and juicy. It's the perfect time to enjoy the harvest and combine the flavors with some autumn spices. Plus, the vibrant colors of the ingredients make it visually appealing!\n",
#   'P1: I totally agree! Fall really does bring out the best in apples and the wonderful spices that accompany them. I often make warm dishes that complement the season, like a hearty apple and butternut squash bake. What other seasonal recipes do you enjoy?\n',
#   "P2: P2: Besides my apple salad, I really enjoy making fruit-based desserts, like a warm apple crisp topped with oats and cinnamon. I also like to whip up smoothies with seasonal fruits, especially when they're at their peak flavor. Lastly, I often experiment with salads that incorporate roasted vegetables and fresh herbs during the spring and summer months!\n",
#   "P1: P1: Those all sound delicious! I love a good apple crisp too, especially with some vanilla ice cream on top. When it comes to summer, I'm all about making caprese salads with fresh tomatoes and basil from my garden.\n",
#   'P2: P2: That sounds amazing! I can imagine how fresh and flavorful the garden tomatoes must be. I’d love to try making a caprese salad with some sliced green apples for a fruity twist!\n',
#   'P1: That sounds like a fun idea! The tartness of green apples would add a nice contrast to the creaminess of the mozzarella. I might just have to experiment with that combination myself!\n',
#   'P2: P2: Definitely give it a try! I think the crunch of the green apples will make it even more enjoyable. Let me know how it turns out!\n'],
#  'pturn': 1,
#  'rounds': 10,
#  'eval_prompt_consistency': [],
#  'P1_prompt_consistency_score': 0,
#  'P2_prompt_consistency_score': 0}

# %%
for conversation in conversations:
    eval_prompt_consistency(conversation, config_gpt4_mini)
conversations
# Out:
# [{'task_name': 'Persona Chat',
#   'P1': ' i like to cook. i have lived in several different states. i worked as a nurse for many years. my husband was a salesman. i have a cat named kj.',
#   'P2': ' i like fruit. my favorite fruit is apple. i don t like to eat meat. i like to eat the skin of the apple. i like green apples.',
#   'conversation': ["P1: P1: Hey! What’s your favorite meal to cook? I love trying out new recipes, especially since I've lived in so many different states and picked up various culinary influences along the way.\n",
#    "P2: I don't really cook meat, so I often make dishes that highlight fruits and vegetables. My favorite is a fresh apple salad with green apples, nuts, and a light dressing. It's simple, delicious, and lets the apple's flavor shine!\n",
#    "NO. The line does not contradict the backstory, as it reflects P2's shy nature and desire to build confidence, which aligns with feeling inspired by others. Being a children’s librarian suggests they are engaged with creativity, and their recent divorce may contribute to their feelings of shyness and need for connection. Overall, the statement emphasizes personal growth and community, which fits with P2's character.",
#    "NO. The line does not contradict P1's backstory, as it speaks to P1's interest in dressing up for others and their understanding of self-expression through style. P1 encourages others to explore fashion, which aligns with their passion for dressing up and caring about appearance.",
#    "NO. The line does not contradict P2's backstory, as it reflects a desire to boost confidence through small changes in appearance, which is consistent with being shy and looking to improve social interactions. Additionally, wanting to experiment with accessories and glasses aligns well with P2 being a children's librarian who may appreciate creativity.",
#    "NO. P1's line about accessories and confidence does not contradict their backstory, as it aligns with their interest in dressing up for others and taking care of their appearance. The focus on how one feels inside also supports the idea of confidence being important to P1, who is an actress.",
#    "NO. The line does not contradict P2's backstory, as being shy does not prevent someone from trying to connect with others, especially children in a library setting. P2 is still seeking to enhance their personal expression and interactions despite their shyness.",
#    "NO. P1's encouragement about unique style and creativity aligns with their interest in dressing up for others, as well as their role as an actress. The line does not contradict any aspect of P1's backstory.",
#    "NO. The line does not contradict the backstory since it demonstrates P2's enthusiasm for fostering self-expression in children, which aligns with their role as a children's librarian. Additionally, being shy doesn't prevent someone from appreciating support and expressing excitement about an initiative. The mention of fun and style can coexist with P2's personality traits."],
#   'P1_prompt_consistency_score': 1.0,
#   'P2_prompt_consistency_score': 1.0},
#  {'task_name': 'Persona Chat',
#   'P1': ' i have 3 science classes. i just started college. i work part time in the campus library. i am living at home but hope to live in the dorms next year. i commute by bus.',
#   'P2': ' my parents raised me as a buddhist. i m from seattle. i work in public relations. my favorite band is bon over. i am a vegan.',
#   'conversation': ["P1: Hey! How's everything going with your classes? I've got a full schedule this semester, balancing three science courses and my part-time job at the library. Are you working on anything interesting right now?\n",
#    "P2: P2: Things are going well! I'm currently focused on a project in public relations that involves promoting a local vegan restaurant, which I've really enjoyed. It's great to merge my work with something I’m passionate about!\n",
#    "P1: P1: That sounds awesome! I love the idea of combining work with your passion. I'm just trying to survive my science courses and maybe will get more involved in projects next semester.\n",
#    "P2: P2: I completely understand the struggle; science courses can be challenging! If you ever want to chat about ideas for projects or need support, I'm here to help. Just keep pushing through; it’ll be worth it in the end!\n",
#    "P1: P1: Thanks, I appreciate that! I might take you up on that offer once I get my footing with the classes. For now, I'll just focus on managing my time between studying and working at the library.\n",
#    "P2: P2: That sounds like a solid plan! Time management is key, and I'm sure you'll find the right balance. Just remember to take breaks and make time for yourself!\n",
#    'P1: P1: Absolutely! I’ve been trying to schedule in some downtime between studying and work at the library, but it can be tough. Hopefully, once I get used to everything, I can enjoy some of the campus life too!\n',
#    "P2: P2: I totally get that! Campus life can be fun, and it's important to make time for socializing and relaxation. Maybe you could check out some events or groups related to your interests to connect with others and unwind a bit!\n",
#    'P1: P1: That’s a great idea! I’m definitely planning to explore some campus events and see what clubs might fit my interests. It would be nice to meet new people outside of my classes and work!\n',
#    'P2: P2: That sounds like a fantastic plan! Engaging with others who share your interests can really enrich your college experience. Let me know if you find any cool events—I’d love to hear about them!\n'],
#   'pturn': 1,
#   'rounds': 10,
#   'eval_prompt_consistency': ["NO. The line does not contradict P1's backst
#    'P2: Thanks, I appreciate that! I’m always open to new music suggestions, especially if it keeps the drive interesting. What other artists do you think I should check out?\n',
#    'P1: P1: I think you’d really enjoy Kygo for those uplifting vibes, and you might like Ed Sheeran for some great storytelling in his songs. Also, give Zedd a listen—his beats are infectious! Let me know if you end up liking any of them!\n',
#    "P2: I'll definitely check out Kygo and Zedd for some catchy beats, and I'm always up for a good story, so Ed Sheeran sounds great too! Thanks for the recommendations! I’ll let you know which ones I end up liking.\n"],
#   'pturn': 1,
#   'rounds': 10,
#   'eval_prompt_consistency': ["NO. The line does not contradict P1's backstory as it aligns with their love for travel and their enjoyment of the Chainsmokers. P1's mention of a trip to the beach and inquiring about travel spots shows an active interest in travel, which is consistent with their backstory. Additionally, expressing interest in the latest Chainsmokers album fits with their stated love for the band.",
#    "NO. The line aligns with P2's backstory, as it mentions their enjoyment of camping in the mountains with their new camper and their profession as a truck driver, which would naturally relate to road playlists. There is no contradiction regarding their activities or interests.",
#    "NO. The line does not contradict P1's backstory, as enjoying camping and discussing music can align with P1's love for travel and appreciation for The Chainsmokers. The interests mentioned seem consistent with a relaxed and adventurous personality.",
#    "NO. The line does not contradict the backstory of P2, as it doesn't provide any information about their profession, physical activity, or personal interests that would conflict with their identity as a truck driver, fitness enthusiast, football fan, or former military member. Instead, it simply shows an interest in music and albums, which is not addressed in the backstory.",
#    "NO. The line does not contradict P1's backstory, as it shows P1's appreciation for the Chainsmokers, which aligns with their stated love for the band. Additionally, expressing interest in music while traveling complements P1's love for travel.",
#    "NO. The line does not contradict P2's backstory as it only describes their music preferences during road trips, which is unrelated to their profession, exercise habits, or military background. This information provides insight into P2's leisure activities without conflicting with any aspect of their backstory.",
#    "NO. P1's line aligns with their love for The Chainsmokers and their openness to exploring music, as they offer to recommend more tracks. There is no contradiction with their backstory as a music enthusiast while also being a lifeguard and having a parent who works offshore.",
#    "NO. The line does not contradict P2's backstory, as it is reasonable for someone who drives a truck for a living to be interested in music suggestions to make their drives more enjoyable. The backstory does not exclude having an interest in music or discussing it with others.",
#    "NO. The line does not contradict P1's backstory because it mentions enjoyment of music and suggests artists that could align with P1's taste. P1's love for The Chainsmokers implies they would likely be open to listening to other similar artists like Kygo and Zedd. Additionally, appreciating storytelling in music does not contradict P1's interests.",
#    "NO. P2's enjoyment of music and willingness to explore new artists does not conflict with their backstory, which focuses on their career, exercise habits, favorite sport, recent purchase, and military background. It simply adds depth to their personality."],
#   'P1_prompt_consistency_score': 1.0,
#   'P2_prompt_consistency_score': 1.0},
#  {'task_name': 'Persona Chat',
#   'P1': ' my wife has terminal cancer. i have 3 children. i am a business man. i love to sing. i am a karate black belt.',
#   'P2': ' traffic makes me mad. i have a long drive to work. i listen to podcasts. i am a diabetic. i like to read.',
#   'conversation': ["P1: P1: I've been keeping myself busy with work, but it's tough with everything going on at home. How about you? What have you been up to lately?\n",
#    'P2: I’ve been driving to work a lot, and the traffic is just driving me nuts! To keep myself entertained, I’ve been listening to podcasts during my commute. Also, I’ve been trying to manage my diabetes while squeezing in some reading whenever I can.\n',
#    "P1: P2: That sounds like a good way to cope with the traffic! Managing your health is so important, and it's great you're finding time to read. I admire your dedication to self-care amidst a busy schedule.\n",
#    "P2: Thanks! I appreciate that. It's definitely a balancing act, but I'm trying to stay on top of things. What kind of work are you keeping busy with?\n",
#    "P1: P1: I'm in the business sector, working on some projects that keep me on my toes. It's been challenging balancing work with my family's situation, but I try to stay focused and support my kids when they need me. Singing helps me unwind after a long day; it’s a good outlet for my emotions.\n",
#    "P2: That sounds really rewarding, even with the challenges involved. It's great that you have singing as an outlet; it must be a nice way to relieve stress after a long day. Do you have any favorite songs you love to sing?\n",
#    "P1: P1: I really enjoy singing classic rock and some heartfelt ballads. There's something about belting out those powerful lyrics that just lifts my spirits. Lately, I've been drawn to songs with messages of hope and resilience.\n",
#    "P2: I love classic rock too! It's amazing how music can uplift our spirits and bring comfort. Do you have a go-to song that really resonates with you?\n",
#    'P1: P1: One of my go-to songs has to be "Don\'t Stop Believin\'" by Journey. Its message of hope and perseverance really resonates with me, especially during tough times. I always feel energized and uplifted when I sing it.\n',
#    'P2: That\'s a fantastic choice! "Don\'t Stop Believin\'" is such an anthem of hope. It really captures that feeling of pushing through adversity, which is something we all need sometimes.\n'],
#   'pturn': 1,
#   'rounds': 10,
#   'eval_prompt_consistency': ["NO. The line does not contradict P1's backstory as it reflects the challenges of balancing work and personal life, especially given the circumstances of having a wife with terminal cancer and three children. It is reasonable for P1 to feel that work is a way to cope with the situation at home.",
#    "NO. The line spoken by P2 is consistent with their backstory, as it mentions driving to work, being frustrated with traffic, listening to podcasts, managing diabetes, and trying to read—all of which align with the details provided in P2's backstory. There is no contradiction in the information.",
#    "NO. The line does not contradict P1's backstory, as it reflects an understanding of self-care and managing a busy life, which could apply to P1's situation with a terminally ill wife and their family responsibilities. Additionally, the focus on coping with traffic and health management is relevant to anyone, including P1, who leads a balanced life despite challenges.",
#    "NO. The line does not contradict P2's backstory, as it does not address any specific aspect of their personal circumstances like traffic, diabetes, or hobbies. Instead, it focuses on the general theme of balancing work and life, which is a relatable topic for anyone, including P2.",
#    "NO. The line does not contradict P1's backstory as it reflects their experience as a businessman balancing work and family, while also incorporating their love for singing as a way to cope with stress.",
#    "NO. The line does not contradict P2's backstory, as P2's frustration with traffic and long drives does not prevent them from appreciating the value of singing as a stress reliever for others. Additionally, P2's interests in podcasts and reading do not imply they cannot engage in a conversation about music. The response appears to be a supportive comment to another person's experience.",
#    "NO. The line does not contradict P1's backstory, as it expresses their love for singing and the uplifting effect of music, which could be especially meaningful during challenging times. Additionally, the mention of hope and resilience aligns with the emotional context of dealing with a loved one’s illness.",
#    "NO. The line does not contradict P2's backstory as it does not address any of the specific issues mentioned, such as traffic, driving, or diabetes. It simply expresses a preference for music, which is not mentioned in the backstory.",
#    "NO. The line expresses P1's enjoyment of singing and reflects a positive attitude, which does not contradict his backstory of dealing with challenging circumstances, such as his wife's terminal illness. It aligns with the idea that he finds solace in music, showcasing resilience during tough times.",
#    "NO. The line does not contradict P2's backstory; it expresses a positive sentiment about a song, which is unrelated to P2's traffic frustrations or personal interests. P2's appreciation for the message of the song doesn't impact their other traits or experiences."],
#   'P1_prompt_consistency_score': 1.0,
#   'P2_prompt_consistency_score': 1.0},
#  {'task_name': 'Persona Chat',
#   'P1': ' both of my parents are doctors. i really wanted to be an actor. i am in love with a girl who is unaware of it. i am in medical school. i do community theater when i am not in school.',
#   'P2': ' i like to go to the movies. i have a pit bull and a chihuahua. i walk more than 2 miles a day. my favorite car is the ford mustang. i worked 3 jobs at the same time for more than 5 years.',
#   'conversation': ['P1: P1: Hey, have you ever thought about what you’d do if you could pursue any career without limitations? I sometimes daydream about being on stage full-time, performing in front of an audience. But then I think about my parents and their expectations for me in medicine.\n',
#    "P2: If I could pursue any career, I’d love to be involved in the film industry, maybe as a director or screenwriter. I’m passionate about storytelling and the movies, and I think it would be amazing to create worlds for others to escape into. But like you, I've got responsibilities that keep me grounded!\n",
#    'P1: P2: That’s really cool! I think storytelling is so powerful, and the film industry is a great way to reach people. Sometimes I wonder if there’s a way to combine my love for acting and medicine—like working on medical dramas or helping with scripts that accurately portray healthcare.\n',
#    'P2: That’s a brilliant idea! Medical dramas need authenticity, and your acting skills would bring a real depth to those portrayals. Plus, you could inspire others while staying true to your passion for medicine!\n',
#    'P1: P2: Thanks! I really appreciate that. Balancing both passions would be a dream come true, and who knows, maybe one day I’ll get to help write a script that shines a light on the medical field while getting to act in it!\n',
#    'P2: That sounds like an amazing goal! Combining your love for acting and medicine could definitely make a meaningful impact. I’d love to see a compelling story that brings both of those worlds together!\n',
#    "P1: P2: Thanks, I appreciate your support! It would be incredible to create something that resonates with people and sparks important conversations about health and wellness. Maybe one day, we'll both find a way to merge our passions in storytelling!\n",
#    "P2: Absolutely! I think there's so much potential for collaboration between the arts and healthcare. Who knows, maybe one day we can create a project together that combines our strengths and passions!\n",
#    'P1: P2: That would be amazing! I can already envision a powerful narrative that highlights the human experience in healthcare while showcasing some incredible performances. Let’s keep that dream alive and inspire each other along the way!\n',
#    'P2: P1, I love that vision! It would be so rewarding to create something that brings awareness and connects with people on a personal level. Let’s definitely keep that dream alive and support each other as we pursue our passions!\n'],
#   'pturn': 1,
#   'rounds': 10,
#   'eval_prompt_consistency': ["NO. P1's line aligns with their backstory, as it reflects their desire to pursue acting despite being in medical school and considering their parents' expectations. The mention of daydreaming about being on stage full-time is consistent with their involvement in community theater.",
#    "NO. P2's desire to pursue a career in the film industry aligns with their interest in movies, which is part of their backstory. Additionally, the mention of responsibilities that keep them grounded does not contradict their backstory of working multiple jobs.",
#    "NO. The line reflects P1's aspirations in acting while acknowledging their current path in medicine, which aligns with their desire to combine both interests in the future. It does not contradict their backstory of being in medical school and still pursuing community theater.",
#    "NO. The line does not contradict P2's backstory, as it does not provide any conflicting information about P2's interests or experiences. It simply reflects a supportive and encouraging sentiment towards another person's potential acting career in medical dramas.",
#    "NO. The line expresses P1's desire to combine their passion for acting with their medical background, which aligns with their current pursuit of both medicine and community theater. It does not contradict their backstory of being in medical school and having a passion for acting.",
#    "NO. The line does not contradict P2's backstory, as it reflects an interest in storytelling and creativity, which can align with someone who enjoys movies. There is nothing in the backstory that suggests P2’s interests are limited or that they cannot appreciate the combination of different fields. P2's work ethic and interests do not exclude them from having opinions on creative goals.",
#    "NO. P1's desire to create something that resonates with people and sparks conversations about health and wellness aligns with their background in medical school and community theater. It shows a merging of their interests in both acting and health, which is consistent with their aspirations.",
#    "NO. The line does not contradict P2's backstory, as it does not provide any information that conflicts with their interests or experiences. P2's enjoyment of collaboration in the arts and healthcare does not detract from their personal hobbies or work history.",
#    "NO. P1's line aligns with their involvement in both healthcare and theater, as they are in medical school and participate in community theater. Their enthusiasm for combining narratives in healthcare with performances does not contradict their aspirations or backstory. P1's dream of being an actor can coexist with their medical studies and passion for storytelling.",
#    "NO. P2's line reflects a supportive and collaborative attitude towards pursuing passions, which does not contradict P2's backstory of hard work and dedication. The enthusiasm for creating something meaningful aligns with their character traits inferred from the backstory."],
#   'P1_prompt_consistency_score': 1.0,
#   'P2_prompt_consistency_score': 1.0},
#  {'task_name': 'Persona Chat',
#   'P1': ' i am weak and selfish , but i want to change. my mind is set on things above. i hate evil. i trust in god. my heart hurts from a broken relationship.',
#   'P2': ' i work in finance. i enjoy playing soccer. i live walking distance from work. i do not like coffee. i rent an apartment.',
#   'conversation': ["P1: P1: I've been reflecting a lot on my past choices, and I really want to make a change in my life. It's hard dealing with the pain from my broken relationship, but I trust that God has a plan for me. How do you find strength when you're feeling weak?\n",
#    'P2: I find strength through the little things in life, like playing soccer, which helps me clear my mind and stay active. Also, having a routine and a supportive network can really make a difference. It’s all about focusing on the positive aspects and taking one step at a time.\n',
#    'P1: P1: That makes so much sense. I need to focus on the little things too and lean on my support system more. Maybe finding a hobby or activity could help me heal and grow stronger.\n',
#    'P2: Absolutely! Hobbies can be a great outlet for your emotions and a way to meet new people. Have you considered trying something new, like joining a local sports club or taking up a creative class?\n',
#    'P1: P1: I think trying a new activity could be really beneficial for me. Maybe I could join a community group or take a class in something I’ve always been interested in. I just want to use this time to grow and heal in a positive way.\n',
#    'P2: That sounds like a wonderful idea! Exploring new interests can bring excitement and a fresh perspective. What types of activities are you thinking about trying?\n',
#    "P1: I'm really interested in taking a painting class or maybe even joining a local volunteering group. I think it would help me express myself and connect with others who share similar values. Plus, giving back could be a great way to combat the selfishness I've been struggling with.\n",
#    "P2: Those both sound like fantastic options! Painting can be a wonderful form of self-expression, and volunteering is a great way to connect with others and make a positive impact. I think you'll find that both activities will help you grow and heal in meaningful ways.\n",
#    "P1: P1: Thank you! I really appreciate your encouragement. I'm excited to explore these avenues and start this new chapter in my life.\n",
#    "P2: I'm glad to hear you're feeling excited about this new chapter! Embracing change can lead to incredible personal growth, and I'm sure you'll find joy in the painting and volunteering. If you ever want to share your experiences, I'm here to listen!\n"],
#   'pturn': 1,
#   'rounds': 10,
#   'eval_prompt_consistency': ["NO. The line does not contradict P1's backstory, as it reflects P1's desire to change, acknowledgment of their weakness, trust in God, and struggle with the pain from a broken relationship. It aligns with P1's stated feelings and goals.",
#    'NO. The line spoken by P2 aligns with the backstory, as it reflects their enjoyment of playing soccer and a positive mindset. There is no mention of anything contradicting the details about their life in finance, dislike for coffee, or living situation.',
#    "NO. The line reflects P1's desire to change and grow stronger, which aligns with their backstory of wanting to overcome weakness and selfishness. It also shows an understanding of the importance of support and healing, which is in line with their feelings of hurt and aspiration.",
#    "NO. The line does not contradict P2's backstory, as it expresses a positive view on hobbies and suggests activities that align with P2's interest in soccer. P2 is likely supportive of joining a local sports club given their enjoyment of soccer. Additionally, the suggestion of a creative class does not conflict with their backstory.",
#    "NO. P1's line expresses a desire for personal growth and healing, which aligns with their intention to change. This aspiration to engage in positive activities reflects their hope for improvement despite their self-acknowledged weaknesses.",
#    "NO. The line does not contradict P2's backstory as it focuses on being open to exploring new interests, which is not incompatible with any of the stated aspects of P2's life. In fact, it shows a willingness to engage in new activities, which could complement their current interests.",
#    "NO. The line does not contradict P1’s backstory, as it reflects P1's desire to change and combat selfishness while also expressing an interest in connecting with others who share similar values. Additionally, wanting to engage in volunteering aligns with P1's intention to give back and pursue a better path.",
#    "NO. The line does not contradict P2's backstory, as it does not reference any details about P2’s job, activities, or preferences. It simply expresses support for the activities of painting and volunteering, which is consistent with a positive outlook.",
#    "NO. The line expresses P1's appreciation and excitement about personal growth, which aligns with their desire to change and focus on positive aspects of life. It reflects a hopeful attitude despite their struggles with weakness and selfishness.",
#    "NO. The line does not contradict P2's backstory, as it does not mention any specific work or personal lifestyle that conflicts with the aspects of P2's life, such as their job in finance or interests. It merely expresses support for someone else's journey, which is consistent with P2's character."],
#   'P1_prompt_consistency_score': 1.0,
#   'P2_prompt_consistency_score': 1.0},
#  {'task_name': 'Persona Chat',
#   'P1': ' i have a collection of video games. i have a very tone body. my wife and i enjoy long sunday drives. my son is a straight a student.',
#   'P2': ' my mom is the best baker in my family. i am in my second year of medical school. i am a hindu living in louisiana. i have two children but i am divorced.',
#   'conversation': ["P1: P1: Hey, have you played any new video games lately? I've been diving into some classics from my collection and it's been a blast!\n",
#    "P2: P2: I haven't had much time for video games lately, especially with medical school and the kids keeping me busy. But I do enjoy a good game when I can squeeze it in! What classics are you playing?\n",
#    'P1: P1: I’ve been revisiting titles like "The Legend of Zelda: Ocarina of Time," "Super Mario 64," and "Final Fantasy VII." They really take me back to my childhood! It’s nice to escape for a bit, even with a busy schedule.\n',
#    'P2: P2: Those are some nostalgic classics! I can see how they would provide a nice escape. What do you enjoy most about revisiting those games?\n',
#    "P1: P1: I love the sense of nostalgia they bring, reminding me of simpler times. The storytelling and characters are so memorable, and I find that the gameplay feels timeless. Plus, it's fun to challenge myself to beat my old high scores!\n",
#    "P2: P2: I totally get that! The storytelling in those games really sticks with you, and it's great to immerse yourself in that world again. Do you have a favorite character from any of those games?\n",
#    'P1: P1: Definitely! I\'d have to say Link from "Zelda," Cloud from "Final Fantasy VII," and Mario himself are my favorites. Each character has such a unique journey and personality that makes them unforgettable. How about you? Any favorite characters from games you enjoyed?\n',
#    'P2: P2: I really love Ellie from "The Last of Us" for her depth and resilience, as well as Nathan Drake from "Uncharted" for his adventurous spirit. And I can\'t forget about Luigi—he\'s always been my underdog favorite with his charm! What about game mechanics or features do you find yourself appreciating more as you revisit these classics?\n',
#    'P1: P1: I really appreciate the simplicity of controls and the creativity in level design in these classics. The puzzles and exploration aspects are so engaging, and they often require thoughtful problem-solving. It’s amazing how timeless some of these mechanics feel even today!\n',
#    "P2: P2: I completely agree! The simplicity often lets the storytelling shine, and those clever puzzles keep you deeply engaged. It's a reminder of how effective great game design can be, even without all the modern bells and whistles!\n"],
#   'pturn': 1,
#   'rounds': 10,
#   'eval_prompt_consistency': ["NO. The line does not contradict P1's backstory, as it aligns with the information that P1 has a collection of video games and enjoys playing them. Additionally, there is no mention of a specific timeframe or type of video games that would conflict with their enjoyment.",
#    "NO. The line does not contradict the backstory, as it aligns with P2's busy life as a medical student and a parent while also expressing a personal interest in video games. The mention of enjoying games when possible fits with their current commitments.",
#    "NO. The line does not contradict P1's backstory; it aligns with their interest in video games and suggests a nostalgic connection to their childhood without conflicting with their current family life or responsibilities.",
#    "NO. The line does not contradict P2's backstory, as it does not involve any specific personal details that would conflict with being a medical student or a divorced parent. P2's appreciation for nostalgic games could be a simple expression of enjoyment that aligns with their personality.",
#    "NO. The line does not contradict P1's backstory, as it aligns with their interest in video games. P1's enjoyment of nostalgia, storytelling, and gameplay challenges fits with having a collection of video games. There is no contradiction regarding their interests or lifestyle.",
#    "NO. The line does not contradict the backstory of P2, as it pertains to discussing games and characters, which is unrelated to P2's personal information about family, education, or religion. Being a medical student and a parent does not preclude someone from enjoying games and storytelling.",
#    "NO. P1's line about favorite video game characters aligns with their backstory of having a collection of video games and suggests an engagement with that hobby. There is no contradiction in expressing opinions about characters from video games they likely own or enjoy.",
#    "NO. The line does not contradict P2's backstory, as enjoying video game characters and mechanics does not conflict with being a medical student or a parent. It simply reflects personal interests that are separate from family, education, or cultural background.",
#    "NO. P1's statement about appreciating classic video games aligns with their backstory of having a collection of video games. There is no contradiction in acknowledging the gameplay aspects of video games.",
#    'NO. The line does not contradict the provided backstory of P2, as it expresses a personal opinion about game design, which is unrelated to their personal life or background. P2’s involvement in medical school and family situation does not affect their ability to have an opinion on gaming.'],
#   'P1_prompt_consistency_score': 1.0,
#   'P2_prompt_consistency_score': 1.0}]

# %%
with open('data/persona/persona_chat2.json', 'w') as f:
        json.dump(conversations, f, indent=4)

# %%
# (2) Takes in dialog, takes in base prompt, checks inconsistencies with every line henceforth 

def eval_all_line_consistency(conv_dict, config):
    conv_dict['eval_all_line_consistency'] = []
    conv_dict['P1_all_line_consistency_score'] = 0
    conv_dict['P2_all_line_consistency_score'] = 0
    p1_utterances = 0
    p2_utterances = 0
    pturn = conv_dict["pturn"]
    for i, line in enumerate(conv_dict["conversation"]):
        if pturn == 1:
            
            prompt = "For the following line spoken by P1, answer YES if the line contradicts any line stated by P1 or P1's provided background, and answer NO if the line does not contradict any line in the provided conversation history of P1 and P1's provided background. P1 has the following backstory:\n" + conv_dict["P1"] + "\nP1 had the following conversation with P2:\n" + "".join(conv_dict["conversation"]) + "\n P1 spoke the following line: \n" + line + "\n\n Answer YES if the line contradicts any line stated by P1 throughout the course of the conversation or P1's provided background, and answer NO if the line does not contradict any line in the provided conversation history of P1 and P1's provided background, followed by 1 sentence of reasoning.\n\n"
            output = completion_create(config['eval_model'], config, prompt)
            conv_dict['eval_all_line_consistency'].append(output)
            if "YES" not in output: # no contradiction
                conv_dict['P1_all_line_consistency_score'] += 1
            p1_utterances += 1
            pturn = 2
        else:

            prompt = "For the following line spoken by P2, answer YES if the line contradicts any line stated by P2 or P2's provided background, and answer NO if the line does not contradict any line in the provided conversation history of P2 and P2's provided background. P2 has the following backstory:\n" + conv_dict["P2"] + "\nP2 had the following conversation with P1:\n" + "".join(conv_dict["conversation"]) + "\n P2 spoke the following line: \n" + line + "\n\n Answer YES if the line contradicts any line stated by P2 throughout the course of the conversation or P2's provided background, and answer NO if the line does not contradict any line in the provided conversation history of P2 and P2's provided background, followed by 1 sentence of reasoning.\n\n"
            output = completion_create(config['eval_model'], config, prompt)
            conv_dict['eval_all_line_consistency'].append(output)
            if "YES" not in output: # no contradiction
                conv_dict['P2_all_line_consistency_score'] += 1
            p2_utterances += 1
            pturn = 1

    conv_dict['P1_all_line_consistency_score'] /= p1_utterances
    conv_dict['P2_all_line_consistency_score'] /= p2_utterances

# %%
for conversation in conversations:
    eval_all_line_consistency(conversation, config_gpt4_mini)
conversations

# %%
# (4) Takes in dialog, takes in base prompt, checks for inconsistency with previous line 

def eval_prev_line_consistency(conv_dict, write=False, write_path='data/persona/persona_chat.json'):
    conv_dict['eval_prev_line_consistency'] = []
    conv_dict['P1_prev_line_consistency_score'] = 0
    conv_dict['P2_prev_line_consistency_score'] = 0
    p1_utterances = 0
    p2_utterances = 0
    pturn = conv_dict["pturn"]
    for i, line in enumerate(conv_dict["conversation"]):
        if pturn == 1:
            
            prompt = "For the following line spoken by P1, answer YES if the line contradicts a previous line stated by P1 or P1's provided background, and answer NO if the line does not contradict the provided conversation history of P1 and P1's provided background. P1 has the following backstory:\n" + conv_dict["P1"] + "\nP1 had the following conversation with P2:\n" + "".join(conv_dict["conversation"][:i]) + "\n P1 spoke the following line: \n" + line + "\n\n Answer YES if the line contradicts a previous line stated by P1 or P1's provided background, and answer NO if the line does not contradict the provided conversation history of P1 and P1's provided background, followed by 1 sentence of reasoning.\n\n"
            output = completion_create(config['eval_model'], config, prompt)
            conv_dict['eval_prev_line_consistency'].append(output)
            if "YES" not in output: # no contradiction
                conv_dict['P1_prev_line_consistency_score'] += 1
            p1_utterances += 1
            pturn = 2
        else:

            prompt = "For the following line spoken by P2, answer YES if the line contradicts a previous line stated by P2 or P2's provided background, and answer NO if the line does not contradict the provided conversation history of P2 and P2's provided background. P2 has the following backstory:\n" + conv_dict["P2"] + "\nP2 had the following conversation with P1:\n" + "".join(conv_dict["conversation"][:i]) + "\n P2 spoke the following line: \n" + line + "\n\n Answer YES if the line contradicts a previous line stated by P2 or P2's provided background, and answer NO if the line does not contradict the provided conversation history of P2 and P2's provided background, followed by 1 sentence of reasoning.\n\n"
            output = completion_create(config['eval_model'], config, prompt)
            conv_dict['eval_prev_line_consistency'].append(output)
            if "YES" not in output: # no contradiction
                conv_dict['P2_prev_line_consistency_score'] += 1
            p2_utterances += 1
            pturn = 1

    conv_dict['P1_prev_line_consistency_score'] /= p1_utterances
    conv_dict['P2_prev_line_consistency_score'] /= p2_utterances

# %%
for conversation in conversations:
    eval_prev_line_consistency(conversation, config_gpt4_mini)
conversations

# %%
with open('data/persona/persona_chat3.json', 'w') as f:
        json.dump(conversations, f, indent=4)
